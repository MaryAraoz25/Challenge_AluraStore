# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda.head()
tienda2.head()
tienda3.head()
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %%
tienda.info()
tienda2.info()
tienda3.info()
tienda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
tienda.shape
tienda2.shape
tienda3.shape
tienda4.shape
# Out:
# (2358, 12)

# %%
tienda.describe()
# Out:
#              Precio  Costo de envío  Calificación  Cantidad de cuotas  \
# count  2.359000e+03     2359.000000   2359.000000         2359.000000
# mean   4.878679e+05    26018.609580      3.976685            2.943196
# std    6.146868e+05    32860.001783      1.415370            2.819897
# min    7.600000e+03        0.000000      1.000000            1.000000
# 25%    5.575000e+04     3100.000000      3.000000            1.000000
# 50%    2.353000e+05    12400.000000      5.000000            1.000000
# 75%    6.781000e+05    36000.000000      5.000000            4.000000
# max    2.977000e+06   160800.000000      5.000000           24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean      5.365283   -74.789417
# std       2.287445     1.217827
# min      -4.215280   -77.281110
# 25%       4.609710   -75.563590
# 50%       4.609710   -74.199040
# 75%       6.251840   -74.081750
# max      11.544440   -67.923900

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
tienda[['lat', 'lon']].head()
# Out:
#         lat       lon
# 0   4.60971 -74.08175
# 1   6.25184 -75.56359
# 2  10.39972 -75.51444
# 3   3.43722 -76.52250
# 4   6.25184 -75.56359

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ## Calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
ingreso_tienda1 = tienda['Precio'].sum()
ingreso_tienda2 = tienda2['Precio'].sum()
ingreso_tienda3 = tienda3['Precio'].sum()
ingreso_tienda4 = tienda4['Precio'].sum()

ingreso_tienda1, ingreso_tienda2, ingreso_tienda3, ingreso_tienda4
# Out:
# (np.float64(1150880400.0),
#  np.float64(1116343500.0),
#  np.float64(1098019600.0),
#  np.float64(1038375700.0))

# %%
ingresos = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Ingreso Total': [
        ingreso_tienda1,
        ingreso_tienda2,
        ingreso_tienda3,
        ingreso_tienda4
    ]
})
ingresos
# Out:
#      Tienda  Ingreso Total
# 0  Tienda 1   1.150880e+09
# 1  Tienda 2   1.116344e+09
# 2  Tienda 3   1.098020e+09
# 3  Tienda 4   1.038376e+09

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
categoria_tienda1 = tienda['Categoría del Producto'].value_counts()
categoria_tienda1
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
tienda2.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
categoria_tienda2 = tienda2['Categoría del Producto'].value_counts()
categoria_tienda2
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
tienda3.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
categoria_tienda3 = tienda3['Categoría del Producto'].value_counts()
categoria_tienda3
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
tienda4.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
categoria_tienda4 = tienda4['Categoría del Producto'].value_counts()
categoria_tienda4
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
categoria_tienda1.head(5).plot(kind='bar')
plt.title('Categorías más vendidas - Tienda 1')
plt.xlabel('Categoría')
plt.ylabel('Cantidad de ventas')
plt.show()

# %%
categoria_tienda2.head(5).plot(kind='bar')
plt.title('Categorías más vendidas - Tienda 2')
plt.xlabel('Categoría')
plt.ylabel('Cantidad de ventas')
plt.show()

# %%
categoria_tienda3.head(5).plot(kind='bar')
plt.title('Categorías más vendidas - Tienda 3')
plt.xlabel('Categoría')
plt.ylabel('Cantidad de ventas')
plt.show()

# %%
categoria_tienda4.head(5).plot(kind='bar')
plt.title('Categorías más vendidas - Tienda 4')
plt.xlabel('Categoría')
plt.ylabel('Cantidad de ventas')
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
tienda4.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
promedio_tienda1 = tienda['Calificación'].mean()
promedio_tienda2 = tienda2['Calificación'].mean()
promedio_tienda3 = tienda3['Calificación'].mean()
promedio_tienda4 = tienda4['Calificación'].mean()

promedio_tienda1, promedio_tienda2, promedio_tienda3, promedio_tienda4
# Out:
# (np.float64(3.976685036032217),
#  np.float64(4.037303942348453),
#  np.float64(4.048325561678677),
#  np.float64(3.9957591178965224))

# %%
calificaciones = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Calificación Promedio': [
        promedio_tienda1,
        promedio_tienda2,
        promedio_tienda3,
        promedio_tienda4
    ]
})
calificaciones
# Out:
#      Tienda  Calificación Promedio
# 0  Tienda 1               3.976685
# 1  Tienda 2               4.037304
# 2  Tienda 3               4.048326
# 3  Tienda 4               3.995759

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
productos_tienda1 = tienda['Producto'].value_counts()

mas_vendido_t1 = productos_tienda1.head(5)
menos_vendido_t1 = productos_tienda1.tail(5)

mas_vendido_t1, menos_vendido_t1
# Out:
# (Producto
#  Microondas          60
#  TV LED UHD 4K       60
#  Armario             60
#  Secadora de ropa    58
#  Mesa de noche       56
#  Name: count, dtype: int64,
#  Producto
#  Ciencia de datos con Python    39
#  Pandereta                      36
#  Olla de presión                35
#  Auriculares con micrófono      33
#  Celular ABXY                   33
#  Name: count, dtype: int64)

# %%
productos_tienda2 = tienda2['Producto'].value_counts()

mas_vendido_t2 = productos_tienda2.head(5)
menos_vendido_t2 = productos_tienda2.tail(5)

mas_vendido_t2, menos_vendido_t2
# Out:
# (Producto
#  Iniciando en programación    65
#  Microondas                   62
#  Batería                      61
#  Guitarra acústica            58
#  Pandereta                    58
#  Name: count, dtype: int64,
#  Producto
#  Auriculares        37
#  Sillón             35
#  Mesa de comedor    34
#  Impresora          34
#  Juego de mesa      32
#  Name: count, dtype: int64)

# %%
productos_tienda3 = tienda3['Producto'].value_counts()

mas_vendido_t3 = productos_tienda3.head(5)
menos_vendido_t3 = productos_tienda3.tail(5)

mas_vendido_t3, menos_vendido_t3
# Out:
# (Producto
#  Kit de bancas      57
#  Mesa de comedor    56
#  Cama king          56
#  Set de ollas       55
#  Mesa de noche      55
#  Name: count, dtype: int64,
#  Producto
#  Guitarra eléctrica         38
#  Set de vasos               36
#  Mochila                    36
#  Microondas                 36
#  Bloques de construcción    35
#  Name: count, dtype: int64)

# %%
productos_tienda4 = tienda4['Producto'].value_counts()

mas_vendido_t4 = productos_tienda4.head(5)
menos_vendido_t4 = productos_tienda4.tail(5)

mas_vendido_t4, menos_vendido_t4
# Out:
# (Producto
#  Cama box                     62
#  Cubertería                   59
#  Dashboards con Power BI      56
#  Cama king                    56
#  Carrito de control remoto    55
#  Name: count, dtype: int64,
#  Producto
#  Refrigerador                   38
#  Ciencia de datos con Python    38
#  Guitarra acústica              37
#  Armario                        34
#  Guitarra eléctrica             33
#  Name: count, dtype: int64)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
envio_prom_t1 = tienda['Costo de envío'].mean()
envio_prom_t2 = tienda2['Costo de envío'].mean()
envio_prom_t3 = tienda3['Costo de envío'].mean()
envio_prom_t4 = tienda4['Costo de envío'].mean()

envio_prom_t1, envio_prom_t2, envio_prom_t3, envio_prom_t4
# Out:
# (np.float64(26018.60958033065),
#  np.float64(25216.235693090293),
#  np.float64(24805.680373039424),
#  np.float64(23459.457167090754))

# %%
envios = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Costo de envío promedio': [
        envio_prom_t1,
        envio_prom_t2,
        envio_prom_t3,
        envio_prom_t4
    ]
})

envios
# Out:
#      Tienda  Costo de envío promedio
# 0  Tienda 1             26018.609580
# 1  Tienda 2             25216.235693
# 2  Tienda 3             24805.680373
# 3  Tienda 4             23459.457167

# %%
categoria_tienda1.head(5).plot(kind='bar')
plt.title('Categorías más vendidas - Tienda 1')
plt.xlabel('Categoría')
plt.ylabel('Cantidad de ventas')
plt.show()

# %%
categoria_tienda3.head(5).plot(kind='barh')
plt.title('Categorías más vendidas - Tienda 3')
plt.xlabel('Categoría')
plt.ylabel('Cantidad de ventas')
plt.show()

# %%
categoria_tienda4.head(5).plot(kind='line')
plt.title('Categorías más vendidas - Tienda 4')
plt.xlabel('Categoría')
plt.ylabel('Cantidad de ventas')
plt.show()

# %% [markdown]
# ## **Informe Final**

# %% [markdown]
# Teniendo en cuenta los análisis realizados, se concluye que la Tienda X es la menos eficiente en comparación con las demás. Esta tienda presenta el menor ingreso total, una menor cantidad y diversidad de ventas por categoría, calificaciones promedio más bajas y varios productos con bajo nivel de ventas. Además, su costo de envío promedio no resulta competitivo para los clientes.
#
# Por estos motivos, se recomienda que el Sr. Juan venda la Tienda X, ya que su desempeño general es inferior al de las otras tiendas y esto permitiría enfocar los recursos en tiendas con mejores resultados o en un nuevo emprendimiento.

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.scatter(tienda['lon'], tienda['lat'], alpha=0.5)
plt.title('Distribución geográfica de ventas - Tienda 1')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.show()

# %%
plt.figure()
plt.scatter(tienda2['lon'], tienda2['lat'], alpha=0.5)
plt.title('Distribución geográfica de ventas - Tienda 2')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.show()

# %%
plt.figure()
plt.scatter(tienda3['lon'], tienda3['lat'], alpha=0.5)
plt.title('Distribución geográfica de ventas - Tienda 3')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.show()

# %%
plt.figure()
plt.scatter(tienda4['lon'], tienda4['lat'], alpha=0.5)
plt.title('Distribución geográfica de ventas - Tienda 4')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.show()
